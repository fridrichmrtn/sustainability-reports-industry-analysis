# %% [markdown]
# # Preliminary exploration
#
# ### External covariates

# %%
import sys
sys.path.append("../code")
from exploration import DataExploration
exploration = DataExploration().load_data()
# filter out not applicable
exploration.data = exploration.data[exploration.data.sector!="Not Applicable"]

# %%
from IPython.display import IFrame, display, HTML
html_skin = f"Number of relevant documents: {exploration.data.shape[0]}."
display(HTML(html_skin))
# Out:
# Number of relevant documents: 4604.

# %%
exploration.plot_covariates();

# %% [markdown]
# ### Texts

# %%
# heavy lifting
exploration = exploration.construct_ngram_stats(range=(1,4))
exploration = exploration.construct_cooc_stats()
exploration = exploration.construct_lda(n_topics=15)

# %%
exploration.plot_text_characteristics();

# %%
exploration.plot_ngram_stats();

# %%
exploration.plot_cooc_stats();

# %%
exploration.plot_lda_top_words();
